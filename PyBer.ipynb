# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt
import statistics as stat
import numpy as np
import pandas as pd

# %%
city_data_location = "PyBer_Analysis/Resources/city_data.csv"
ride_data_location = "PyBer_Analysis/Resources/ride_data.csv"

city_data_df = pd.read_csv(city_data_location)
ride_data_df = pd.read_csv(ride_data_location)

# %%
city_data_df
# Out:
#                 city  driver_count   type
# 0        Richardfort            38  Urban
# 1       Williamsstad            59  Urban
# 2        Port Angela            67  Urban
# 3         Rodneyfort            34  Urban
# 4        West Robert            39  Urban
# ..               ...           ...    ...
# 115     Bradshawfurt             7  Rural
# 116     New Ryantown             2  Rural
# 117   Randallchester             9  Rural
# 118      Jessicaport             1  Rural
# 119  South Saramouth             7  Rural
#
# [120 rows x 3 columns]

# %%
ride_data_df
# Out:
#                     city                 date   fare        ride_id
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
# [2375 rows x 4 columns]

# %%
grouped_df = city_data_df.set_index(['city'])
grouped_df['Number of rides'] = ride_data_df.groupby(['city']).count()['ride_id']
grouped_df.index.name = None
grouped_df
# Out:
#                  driver_count   type  Number of rides
# Richardfort                38  Urban               28
# Williamsstad               59  Urban               23
# Port Angela                67  Urban               19
# Rodneyfort                 34  Urban               23
# West Robert                39  Urban               31
# ...                       ...    ...              ...
# Bradshawfurt                7  Rural               10
# New Ryantown                2  Rural                6
# Randallchester              9  Rural                5
# Jessicaport                 1  Rural                6
# South Saramouth             7  Rural                4
#
# [120 rows x 3 columns]

# %%
grouped_df['Total Fares'] = ride_data_df.groupby(['city']).sum()['fare']
grouped_df['Average Fare'] = ride_data_df.groupby(['city']).mean()['fare']
grouped_df
# Out:
#                  driver_count   type  Number of rides  Total Fares  \
# Richardfort                38  Urban               28       626.45
# Williamsstad               59  Urban               23       560.33
# Port Angela                67  Urban               19       452.90
# Rodneyfort                 34  Urban               23       658.19
# West Robert                39  Urban               31       778.84
# ...                       ...    ...              ...          ...
# Bradshawfurt                7  Rural               10       400.64
# New Ryantown                2  Rural                6       259.67
# Randallchester              9  Rural                5       148.71
# Jessicaport                 1  Rural                6       216.08
# South Saramouth             7  Rural                4       144.64
#
#                  Average Fare
# Richardfort         22.373214
# Williamsstad        24.362174
# Port Angela         23.836842
# Rodneyfort          28.616957
# ...

# %%
city_type_df = grouped_df.groupby(['type']).count()['Number of rides']
city_type_df
# Out:
# type
# Rural       18
# Suburban    36
# Urban       66
# Name: Number of rides, dtype: int64

# %%
city_type_df = pd.DataFrame(city_type_df)
city_type_df.index.name = None
city_type_df
# Out:
#           Number of rides
# Rural                  18
# Suburban               36
# Urban                  66

# %%
city_type_df['Drivers'] = grouped_df.groupby(['type']).sum()['driver_count']
city_type_df['Average Fare'] = grouped_df.groupby(['type']).mean()['Average Fare']
city_type_df
# Out:
#           Number of rides  Drivers  Average Fare
# Rural                  18       78     34.637765
# Suburban               36      490     30.737298
# Urban                  66     2405     24.499122

# %%
# Merging Data
pyber_data_df = pd.merge(ride_data_df, city_data_df, how='left', on=['city','city'])

pyber_data_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# ...
